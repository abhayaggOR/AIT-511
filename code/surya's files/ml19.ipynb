# %%
# ==============================================================
# Gender-split XGBoost + BMI + OHE + EarlyStopping
# Optuna CV + CLASS WEIGHTS for Overweight I & II
# GPU-enabled (gpu_hist) with safe CPU fallback
# Prints trial/fold progress and GPU usage
# Uses: train_combined.csv  → submission.csv
# ==============================================================

import os
import numpy as np
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import OneHotEncoder, StandardScaler, LabelEncoder
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, f1_score

import xgboost as xgb
import optuna
from contextlib import suppress

# %%
# ---------------- Config ----------------
TRAIN_PATH = "train_combined.csv"
TEST_PATH  = "test.csv"
SAMPLE_SUB_PATH = "sample_submission.csv"

RANDOM_STATE = 42
N_JOBS = -1
N_FOLDS = 5
EARLY_STOP = 200

# Tuning budget
TRIALS_MALE = 30
TRIALS_FEMALE = 30

# Multi-seed CV
CV_SEEDS = [42, 2027, 1337]

# >>> Class weights for Overweight classes <<<
W_OVR1 = 1.6   # Overweight Level I
W_OVR2 = 1.6   # Overweight Level II

# >>> Progress / logging <<<
PRINT_EVERY = 200          # print eval metric every N boosting rounds (set 0 to silence)
SHOW_PARAMS_PER_TRIAL = True

# >>> Prefer GPU if available <<<
USE_GPU = True  # set False to force CPU

GPU_STATUS = {"requested": USE_GPU, "used_any": False}

# %%
def want_gpu_params():
    # device is honored by XGBoost 2.x; ignored by older
    return {"tree_method": "gpu_hist", "predictor": "gpu_predictor", "device": "cuda"}

def apply_device(params, want_gpu=True):
    p = dict(params)
    if want_gpu:
        p.update(want_gpu_params())
    else:
        p.update({"tree_method": "hist", "predictor": "auto"})
    return p

def make_dmatrix(X, y=None, weight=None, use_gpu=False):
    """Use fast DeviceQuantileDMatrix on GPU, fallback to classic DMatrix."""
    if use_gpu:
        with suppress(Exception):
            return xgb.DeviceQuantileDMatrix(X, label=y, weight=weight)
    return xgb.DMatrix(X, label=y, weight=weight)

def has_gpu(params):
    return params.get("tree_method") == "gpu_hist"

# ---------------- Helpers ----------------
def add_bmi(df):
    if ("Weight" in df.columns) and ("Height" in df.columns):
        h = df["Height"].astype(float)
        hm = np.where(h.median() > 3.0, h/100.0, h)
        with np.errstate(divide="ignore", invalid="ignore"):
            bmi = df["Weight"].astype(float) / (hm**2 + 1e-12)
        df["BMI"] = pd.Series(bmi).replace([np.inf, -np.inf], np.nan).clip(10, 80)
    return df

def make_preprocessor(num_cols, cat_cols):
    num_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="median")),
        ("scaler", StandardScaler(with_mean=False))
    ])
    try:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse_output=True)
    except TypeError:
        ohe = OneHotEncoder(handle_unknown="ignore", sparse=True)
    cat_pipe = Pipeline([
        ("imputer", SimpleImputer(strategy="most_frequent")),
        ("onehot", ohe),
    ])
    return ColumnTransformer(
        transformers=[
            ("num", num_pipe, num_cols),
            ("cat", cat_pipe, cat_cols)
        ],
        remainder="drop",
        sparse_threshold=1.0
    )

def detect_gender(df):
    for c in df.columns:
        if c.lower() in ("gender","sex"):
            return c
    raise ValueError("Could not detect gender column (expected Gender or Sex).")

def infer_cols(df):
    cat_cols = df.select_dtypes(include=["object","category","bool"]).columns.tolist()
    num_cols = df.select_dtypes(include=[np.number]).columns.tolist()
    return num_cols, cat_cols

def norm_label(s: str) -> str:
    s = str(s)
    return "".join(ch for ch in s.lower() if ch.isalnum())

OVERWEIGHT1_ALIASES = {
    "overweightleveli","overweightlevel1","overweight_level_i","overweighti"
}
OVERWEIGHT2_ALIASES = {
    "overweightlevelii","overweightlevel2","overweight_level_ii","overweightii"
}

def build_class_weights(y_series: pd.Series, w1=W_OVR1, w2=W_OVR2):
    w = np.ones(len(y_series), dtype=np.float32)
    y_norm = y_series.astype(str).map(norm_label)
    w[(y_norm.isin(OVERWEIGHT1_ALIASES)).values] = float(w1)
    w[(y_norm.isin(OVERWEIGHT2_ALIASES)).values] = float(w2)
    return w

def suggest_params(trial):
    return {
        "eta": trial.suggest_float("eta", 0.02, 0.06, log=True),
        "max_depth": trial.suggest_int("max_depth", 5, 8),
        "min_child_weight": trial.suggest_float("min_child_weight", 1.0, 4.5),
        "subsample": trial.suggest_float("subsample", 0.75, 0.95),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.70, 0.95),
        "reg_lambda": trial.suggest_float("reg_lambda", 0.8, 2.5, log=True),
        "reg_alpha": trial.suggest_float("reg_alpha", 0.0, 0.6),
        "gamma": trial.suggest_float("gamma", 0.0, 0.4),
        "max_delta_step": trial.suggest_float("max_delta_step", 0.0, 3.0),
        "num_boost_round": trial.suggest_int("num_boost_round", 2000, 12000, step=1000),
    }

def _verbose_eval():
    # return False to silence; or integer N to print every N rounds
    return False if PRINT_EVERY <= 0 else PRINT_EVERY

# %%
# ---------------- Tuning & Training (uses weights) ----------------
def tune_group(Xg, yg_enc, y_labels_grp, label, num_class, trials):
    num_cols, cat_cols = infer_cols(Xg)
    weights_grp = build_class_weights(y_labels_grp)

    def objective(trial):
        hp = suggest_params(trial)
        if SHOW_PARAMS_PER_TRIAL:
            print(f"\n[{label}] Trial {trial.number+1}/{trials} | "
                  f"eta={hp['eta']:.4f}, depth={hp['max_depth']}, "
                  f"mcw={hp['min_child_weight']:.2f}, subsample={hp['subsample']:.2f}, "
                  f"colsample={hp['colsample_bytree']:.2f}, rounds={hp['num_boost_round']}")

        scores_across_seeds = []
        base_params = {
            "objective": "multi:softprob",
            "num_class": num_class,
            "eval_metric": "mlogloss",
            "eta": hp["eta"],
            "max_depth": int(hp["max_depth"]),
            "min_child_weight": float(hp["min_child_weight"]),
            "subsample": float(hp["subsample"]),
            "colsample_bytree": float(hp["colsample_bytree"]),
            "reg_lambda": float(hp["reg_lambda"]),
            "reg_alpha": float(hp["reg_alpha"]),
            "gamma": float(hp["gamma"]),
            "max_delta_step": float(hp["max_delta_step"]),
            "nthread": N_JOBS,
            "verbosity": 0,
        }

        for cv_seed in CV_SEEDS:
            skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=cv_seed)
            fold_scores = []

            for fold_id, (tr_idx, va_idx) in enumerate(skf.split(Xg, yg_enc), start=1):
                print(f"[{label}] Trial {trial.number+1}/{trials} • Seed {cv_seed} • Fold {fold_id}/{N_FOLDS}")
                X_tr, X_va = Xg.iloc[tr_idx], Xg.iloc[va_idx]
                y_tr, y_va = yg_enc[tr_idx], yg_enc[va_idx]
                w_tr = weights_grp[tr_idx]

                pre = make_preprocessor(num_cols, cat_cols)
                Xtr = pre.fit_transform(X_tr)
                Xva = pre.transform(X_va)

                params_try = apply_device(base_params, want_gpu=USE_GPU)
                use_gpu = has_gpu(params_try)

                dtrain = make_dmatrix(Xtr, y_tr, w_tr, use_gpu)
                dvalid = make_dmatrix(Xva, y_va, None, use_gpu)

                try:
                    bst = xgb.train(
                        params=params_try,
                        dtrain=dtrain,
                        num_boost_round=hp["num_boost_round"],
                        evals=[(dtrain, "train"), (dvalid, "valid")],
                        early_stopping_rounds=EARLY_STOP,
                        verbose_eval=_verbose_eval()
                    )
                    if use_gpu and not GPU_STATUS["used_any"]:
                        GPU_STATUS["used_any"] = True
                        print(f"[{label}] ✅ GPU is being used (tree_method=gpu_hist, predictor=gpu_predictor).")
                except xgb.core.XGBoostError as e:
                    if USE_GPU:
                        print(f"[{label}] ⚠️ GPU unavailable → CPU fallback. Reason: {e}")
                    params_cpu = apply_device(base_params, want_gpu=False)
                    dtrain = make_dmatrix(Xtr, y_tr, w_tr, use_gpu=False)
                    dvalid = make_dmatrix(Xva, y_va, None, use_gpu=False)
                    bst = xgb.train(
                        params=params_cpu,
                        dtrain=dtrain,
                        num_boost_round=hp["num_boost_round"],
                        evals=[(dtrain, "train"), (dvalid, "valid")],
                        early_stopping_rounds=EARLY_STOP,
                        verbose_eval=_verbose_eval()
                    )

                pred_va = bst.predict(dvalid, iteration_range=(0, bst.best_iteration + 1))
                y_hat = np.argmax(pred_va, axis=1)
                acc = accuracy_score(y_va, y_hat)
                fold_scores.append(acc)
                print(f"[{label}]   Fold {fold_id} Acc={acc:.5f} | best_iter={bst.best_iteration+1}")

            mean_seed_score = float(np.mean(fold_scores))
            scores_across_seeds.append(mean_seed_score)
            trial.report(np.mean(scores_across_seeds), step=len(scores_across_seeds))

        mean_score = float(np.mean(scores_across_seeds))
        print(f"[{label}] Trial {trial.number+1} mean Acc over seeds: {mean_score:.5f}")
        return mean_score

    study = optuna.create_study(direction="maximize")
    print(f"\n[{label}] Robust tuning (weighted): {trials} trials × {len(CV_SEEDS)} seeds × {N_FOLDS}-fold")
    print(f"[INFO] XGBoost {xgb.__version__} | GPU requested: {USE_GPU}")
    study.optimize(objective, n_trials=trials, show_progress_bar=True)

    print(f"[{label}] Best CV Acc: {study.best_value:.5f}")
    print(f"[{label}] Best params:\n{study.best_params}")
    return study.best_params

def train_cv_predict(Xg, yg_enc, y_labels_grp, Xtestg, params, num_class, label):
    num_cols, cat_cols = infer_cols(Xg)
    weights_grp = build_class_weights(y_labels_grp)

    skf = StratifiedKFold(n_splits=N_FOLDS, shuffle=True, random_state=RANDOM_STATE)
    oof = np.zeros((len(Xg), num_class), dtype=np.float32)
    test_pred = np.zeros((len(Xtestg), num_class), dtype=np.float32)
    best_iters = []

    base_params = {
        "objective": "multi:softprob",
        "num_class": num_class,
        "eval_metric": "mlogloss",
        "nthread": N_JOBS,
        "seed": RANDOM_STATE,
        "verbosity": 0,
        "eta": float(params["eta"]),
        "max_depth": int(params["max_depth"]),
        "min_child_weight": float(params["min_child_weight"]),
        "subsample": float(params["subsample"]),
        "colsample_bytree": float(params["colsample_bytree"]),
        "reg_lambda": float(params["reg_lambda"]),
        "reg_alpha": float(params["reg_alpha"]),
        "gamma": float(params["gamma"]),
        "max_delta_step": float(params["max_delta_step"]),
    }

    for fold, (tr_idx, va_idx) in enumerate(skf.split(Xg, yg_enc), start=1):
        print(f"[{label}] Final CV • Fold {fold}/{N_FOLDS}")
        X_tr, X_va = Xg.iloc[tr_idx], Xg.iloc[va_idx]
        y_tr, y_va = yg_enc[tr_idx], yg_enc[va_idx]
        w_tr = weights_grp[tr_idx]

        pre = make_preprocessor(num_cols, cat_cols)
        Xtr = pre.fit_transform(X_tr)
        Xva = pre.transform(X_va)
        Xte = pre.transform(Xtestg)

        params_try = apply_device(base_params, want_gpu=USE_GPU)
        use_gpu = has_gpu(params_try)

        dtrain = make_dmatrix(Xtr, y_tr, w_tr, use_gpu)
        dvalid = make_dmatrix(Xva, y_va, None, use_gpu)
        dtest  = make_dmatrix(Xte, None, None, use_gpu)

        try:
            bst = xgb.train(
                params=params_try,
                dtrain=dtrain,
                num_boost_round=int(params["num_boost_round"]),
                evals=[(dtrain, "train"), (dvalid, "valid")],
                early_stopping_rounds=EARLY_STOP,
                verbose_eval=_verbose_eval()
            )
            if use_gpu and not GPU_STATUS["used_any"]:
                GPU_STATUS["used_any"] = True
                print(f"[{label}] ✅ GPU is being used (tree_method=gpu_hist, predictor=gpu_predictor).")
        except xgb.core.XGBoostError as e:
            if USE_GPU:
                print(f"[{label}] ⚠️ GPU unavailable → CPU fallback. Reason: {e}")
            params_cpu = apply_device(base_params, want_gpu=False)
            dtrain = make_dmatrix(Xtr, y_tr, w_tr, use_gpu=False)
            dvalid = make_dmatrix(Xva, y_va, None, use_gpu=False)
            dtest  = make_dmatrix(Xte, None, None, use_gpu=False)
            bst = xgb.train(
                params=params_cpu,
                dtrain=dtrain,
                num_boost_round=int(params["num_boost_round"]),
                evals=[(dtrain, "train"), (dvalid, "valid")],
                early_stopping_rounds=EARLY_STOP,
                verbose_eval=_verbose_eval()
            )

        best_iters.append(int(bst.best_iteration + 1))
        oof[va_idx] = bst.predict(dvalid, iteration_range=(0, bst.best_iteration + 1))
        test_pred += bst.predict(dtest, iteration_range=(0, bst.best_iteration + 1)) / N_FOLDS

        print(f"[{label}]   Fold {fold} best_iter={best_iters[-1]}")

    y_oof = np.argmax(oof, axis=1)
    print(f"[{label}] OOF Acc: {accuracy_score(yg_enc, y_oof):.5f} | "
          f"OOF F1: {f1_score(yg_enc, y_oof, average='macro'):.5f} | "
          f"median best_iter: {int(np.median(best_iters))}")
    return test_pred

# %%
# ==============================================================
# Load & Prepare
# ==============================================================

print(f"[INFO] XGBoost version: {xgb.__version__} | USE_GPU={USE_GPU}")
train = pd.read_csv(TRAIN_PATH)
test  = pd.read_csv(TEST_PATH)
sample_sub = pd.read_csv(SAMPLE_SUB_PATH)

# Drop columns you don’t want
for c in ["MTRANS","SMOKE"]:
    if c in train.columns: train.drop(columns=[c], inplace=True)
    if c in test.columns:  test.drop(columns=[c], inplace=True)

# Add BMI
train = add_bmi(train)
test  = add_bmi(test)

# Detect ID/Target
ID_COL, TARGET_COL = sample_sub.columns[0], sample_sub.columns[1]

y = train[TARGET_COL].copy()
X = train.drop(columns=[TARGET_COL, ID_COL], errors="ignore")
test_ids = test[ID_COL]
test_X = test.drop(columns=[ID_COL], errors="ignore")

# Label encode target
le = LabelEncoder()
y_enc = le.fit_transform(y)
classes = le.classes_
num_class = len(classes)

# Gender split
gender_col = detect_gender(X)
male_mask   = X[gender_col].astype(str).str.lower().str.startswith(("m"))
female_mask = X[gender_col].astype(str).str.lower().str.startswith(("f"))
test_male_mask   = test_X[gender_col].astype(str).str.lower().str.startswith(("m"))
test_female_mask = test_X[gender_col].astype(str).str.lower().str.startswith(("f"))

print(f"[INFO] Train: males={male_mask.sum()}, females={female_mask.sum()}")
print(f"[INFO] Test:  males={test_male_mask.sum()}, females={test_female_mask.sum()}")

# Split: X, y (encoded), AND the original string labels for weight computation
X_male     = X[male_mask].reset_index(drop=True)
y_male_enc = y_enc[male_mask]
y_male_lbl = y[male_mask].reset_index(drop=True)

X_female     = X[female_mask].reset_index(drop=True)
y_female_enc = y_enc[female_mask]
y_female_lbl = y[female_mask].reset_index(drop=True)

test_male   = test_X[test_male_mask].reset_index(drop=True)
test_female = test_X[test_female_mask].reset_index(drop=True)
# Out:
# [INFO] XGBoost version: 2.0.0 | USE_GPU=True
# [INFO] Train: males=8851, females=8793
# [INFO] Test:  males=10336, females=10422

# %%
# ==============================================================
# Tune (weighted) per gender
# ==============================================================

best_male   = tune_group(X_male, y_male_enc, y_male_lbl, "MALE",   num_class, TRIALS_MALE)
best_female = tune_group(X_female, y_female_enc, y_female_lbl, "FEMALE", num_class, TRIALS_FEMALE)

# ==============================================================
# Train with best params and predict (5-fold avg, weighted)
# ==============================================================

pred_male   = train_cv_predict(X_male, y_male_enc, y_male_lbl, test_male,   best_male,   num_class, "MALE")
pred_female = train_cv_predict(X_female, y_female_enc, y_female_lbl, test_female, best_female, num_class, "FEMALE")

# Merge predictions and build submission
final_proba = np.zeros((len(test_X), num_class), dtype=np.float32)
final_proba[test_male_mask.values]   = pred_male
final_proba[test_female_mask.values] = pred_female
final_pred = le.inverse_transform(np.argmax(final_proba, axis=1))

sub = pd.DataFrame({ID_COL: test_ids, TARGET_COL: final_pred})
sub.to_csv("submission.csv", index=False)
print("\nSaved submission.csv ✅")
print(sub.head())

# Final GPU summary
if GPU_STATUS["requested"]:
    print(f"\n[SUMMARY] GPU requested ✔ | GPU actually used at least once: {GPU_STATUS['used_any']}")
else:
    print("\n[SUMMARY] GPU not requested (forced CPU).")
# Out:
# [I 2025-10-23 18:32:36,176] A new study created in memory with name: no-name-89b7c42e-c285-43f3-a265-844edbda73bd
# [MALE] Robust tuning (weighted): 30 trials × 3 seeds × 5-fold
# [INFO] XGBoost 2.0.0 | GPU requested: True
#   0%|          | 0/30 [00:00<?, ?it/s]
# [MALE] Trial 1/30 | eta=0.0213, depth=6, mcw=2.20, subsample=0.88, colsample=0.71, rounds=9000
# [MALE] Trial 1/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.89546	valid-mlogloss:1.89651
# [200]	train-mlogloss:0.27496	valid-mlogloss:0.33474
# [400]	train-mlogloss:0.18163	valid-mlogloss:0.29367
# [600]	train-mlogloss:0.13896	valid-mlogloss:0.29043
# [800]	train-mlogloss:0.10892	valid-mlogloss:0.29228
# [MALE] ✅ GPU is being used (tree_method=gpu_hist, predictor=gpu_predictor).
# [MALE]   Fold 1 Acc=0.89893 | best_iter=602
# [MALE] Trial 1/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.89518	valid-mlogloss:1.89635
# [200]	train-mlogloss:0.27255	valid-mlogloss:0.36170
# [400]	train-mlogloss:0.18075	valid-mlogloss:0.31560
# [600]	train-mlogloss:0.13857	valid-mlogloss:0.31038
# [800]	train-mlogloss:0.10922	valid-mlogloss:0.31224
# [825]	train-mlogloss:0.10599	valid-mlogloss:0.31279
# [MALE]   Fold 2 Acc=0.89040 | best_iter=627
# [MALE] Trial 1/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.89530	valid-mlogloss:1.89615
# [200]	train-mlogloss:0.27105	valid-mlogloss:0.36366
# [400]	train-mlogloss:0.17993	valid-mlogloss:0.32942
# [600]	train-mlogloss:0.13773	valid-mlogloss:0.33072
# [662]	train-mlogloss:0.12824	valid-mlogloss:0.33168
# [MALE]   Fold 3 Acc=0.88531 | best_iter=463
# [MALE] Trial 1/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.89533	valid-mlogloss:1.89631
# [200]	train-mlogloss:0.27467	valid-mlogloss:0.35911
# [400]	train-mlogloss:0.18261	valid-mlogloss:0.31540
# [600]	train-mlogloss:0.14096	valid-mlogloss:0.31061
# [794]	train-mlogloss:0.11185	valid-mlogloss:0.31179
# [MALE]   Fold 4 Acc=0.89379 | best_iter=596
# [MALE] Trial 1/30 • Seed 42 • Fold 5/5
# [0]	train-mlogloss:1.89230	valid-mlogloss:1.89155
# [200]	train-mlogloss:0.27888	valid-mlogloss:0.32067
# [400]	train-mlogloss:0.18680	valid-mlogloss:0.27637
# [600]	train-mlogloss:0.14407	valid-mlogloss:0.27290
# [721]	train-mlogloss:0.12452	valid-mlogloss:0.27434
# [MALE]   Fold 5 Acc=0.90621 | best_iter=523
# [MALE] Trial 1/30 • Seed 2027 • Fold 1/5
# [0]	train-mlogloss:1.89578	valid-mlogloss:1.89637
# [200]	train-mlogloss:0.27857	valid-mlogloss:0.33112
# [400]	train-mlogloss:0.18469	valid-mlogloss:0.29085
# [600]	train-mlogloss:0.14241	valid-mlogloss:0.28987
# [698]	train-mlogloss:0.12645	valid-mlogloss:0.29005
# [MALE]   Fold 1 Acc=0.90288 | best_iter=500
# [MALE] Trial 1/30 • Seed 2027 • Fold 2/5
# [0]	train-mlogloss:1.89195	valid-mlogloss:1.89134
# [200]	train-mlogloss:0.27353	valid-mlogloss:0.33797
# [400]	train-mlogloss:0.18214	valid-mlogloss:0.30184
# [600]	train-mlogloss:0.13885	valid-mlogloss:0.30114
# [725]	train-mlogloss:0.11832	valid-mlogloss:0.30419
# [MALE]   Fold 2 Acc=0.89322 | best_iter=527
# [MALE] Trial 1/30 • Seed 2027 • Fold 3/5
# [0]	train-mlogloss:1.89515	valid-mlogloss:1.89700
# [MALE]   Fold 4 Acc=0.89605 | best_iter=564
# [MALE] Trial 1/30 • Seed 1337 • Fold 5/5
# [0]	train-mlogloss:1.89561	valid-mlogloss:1.89571
# [200]	train-mlogloss:0.27734	valid-mlogloss:0.34266
# [400]	train-mlogloss:0.18542	valid-mlogloss:0.30071
# [600]	train-mlogloss:0.14300	valid-mlogloss:0.29747
# [762]	train-mlogloss:0.11747	valid-mlogloss:0.29962
# [MALE]   Fold 5 Acc=0.89944 | best_iter=563
# [MALE] Trial 1 mean Acc over seeds: 0.89568
# [I 2025-10-23 18:37:57,046] Trial 0 finished with value: 0.8956796940879476 and parameters: {'eta': 0.021264872333865367, 'max_depth': 6, 'min_child_weight': 2.2049554076500932, 'subsample': 0.8821270882393568, 'colsample_bytree': 0.7075071852304274, 'reg_lambda': 2.3163006234653207, 'reg_alpha': 0.30862790019421527, 'gamma': 0.028906784812222776, 'max_delta_step': 0.7375994469554685, 'num_boost_round': 9000}. Best is trial 0 with value: 0.8956796940879476.
#
# [MALE] Trial 2/30 | eta=0.0202, depth=6, mcw=4.10, subsample=0.89, colsample=0.74, rounds=9000
# [MALE] Trial 2/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.89703	valid-mlogloss:1.89795
# [200]	train-mlogloss:0.28135	valid-mlogloss:0.33936
# [400]	train-mlogloss:0.18785	valid-mlogloss:0.29654
# [600]	train-mlogloss:0.14482	valid-mlogloss:0.29234
# [800]	train-mlogloss:0.11510	valid-mlogloss:0.29435
# [801]	train-mlogloss:0.11500	valid-mlogloss:0.29437
# [MALE]   Fold 1 Acc=0.89554 | best_iter=602
# [MALE] Trial 2/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.89678	valid-mlogloss:1.89826
# [200]	train-mlogloss:0.27908	valid-mlogloss:0.36260
# [400]	train-mlogloss:0.18691	valid-mlogloss:0.31567
# [600]	train-mlogloss:0.14415	valid-mlogloss:0.31098
# [755]	train-mlogloss:0.12056	valid-mlogloss:0.31289
# [MALE]   Fold 2 Acc=0.89040 | best_iter=556
# [MALE] Trial 2/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.89684	valid-mlogloss:1.89766
# [200]	train-mlogloss:0.27850	valid-mlogloss:0.36646
# [400]	train-mlogloss:0.18626	valid-mlogloss:0.32969
# [600]	train-mlogloss:0.14321	valid-mlogloss:0.33063
# [662]	train-mlogloss:0.13329	valid-mlogloss:0.33197
# [MALE]   Fold 3 Acc=0.88588 | best_iter=463
# [MALE] Trial 2/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.89697	valid-mlogloss:1.89803
# [200]	train-mlogloss:0.28063	valid-mlogloss:0.36297
# [400]	train-mlogloss:0.18868	valid-mlogloss:0.31836
# [600]	train-mlogloss:0.14683	valid-mlogloss:0.31405
# [795]	train-mlogloss:0.11812	valid-mlogloss:0.31573
# [MALE]   Fold 4 Acc=0.89379 | best_iter=597
# [MALE] Trial 2/30 • Seed 42 • Fold 5/5
# [MALE]   Fold 1 Acc=0.90344 | best_iter=555
# [MALE] Trial 2/30 • Seed 1337 • Fold 2/5
# [0]	train-mlogloss:1.89676	valid-mlogloss:1.89810
# [200]	train-mlogloss:0.27857	valid-mlogloss:0.36830
# [400]	train-mlogloss:0.18664	valid-mlogloss:0.32515
# [600]	train-mlogloss:0.14384	valid-mlogloss:0.32341
# [731]	train-mlogloss:0.12426	valid-mlogloss:0.32606
# [MALE]   Fold 2 Acc=0.88079 | best_iter=533
# [MALE] Trial 2/30 • Seed 1337 • Fold 3/5
# [0]	train-mlogloss:1.89697	valid-mlogloss:1.89798
# [200]	train-mlogloss:0.28265	valid-mlogloss:0.35195
# [400]	train-mlogloss:0.19024	valid-mlogloss:0.30232
# [600]	train-mlogloss:0.14641	valid-mlogloss:0.29751
# [800]	train-mlogloss:0.11703	valid-mlogloss:0.29850
# [868]	train-mlogloss:0.10923	valid-mlogloss:0.29964
# [MALE]   Fold 3 Acc=0.89322 | best_iter=670
# [MALE] Trial 2/30 • Seed 1337 • Fold 4/5
# [0]	train-mlogloss:1.89720	valid-mlogloss:1.89817
# [200]	train-mlogloss:0.28429	valid-mlogloss:0.33603
# [400]	train-mlogloss:0.19008	valid-mlogloss:0.29343
# [600]	train-mlogloss:0.14745	valid-mlogloss:0.29154
# [758]	train-mlogloss:0.12344	valid-mlogloss:0.29404
# [MALE]   Fold 4 Acc=0.89774 | best_iter=560
# [MALE] Trial 2/30 • Seed 1337 • Fold 5/5
# [0]	train-mlogloss:1.89719	valid-mlogloss:1.89736
# [200]	train-mlogloss:0.28337	valid-mlogloss:0.34474
# [400]	train-mlogloss:0.19177	valid-mlogloss:0.30188
# [600]	train-mlogloss:0.14863	valid-mlogloss:0.29838
# [782]	train-mlogloss:0.12069	valid-mlogloss:0.30205
# [MALE]   Fold 5 Acc=0.89944 | best_iter=584
# [MALE] Trial 2 mean Acc over seeds: 0.89500
# [I 2025-10-23 18:42:11,720] Trial 1 finished with value: 0.8950018130563452 and parameters: {'eta': 0.020240981701305776, 'max_depth': 6, 'min_child_weight': 4.099355393726922, 'subsample': 0.8912248992396645, 'colsample_bytree': 0.7354462491373462, 'reg_lambda': 1.0571314976116872, 'reg_alpha': 0.15935137767480753, 'gamma': 0.1687293420609083, 'max_delta_step': 1.1129967212535172, 'num_boost_round': 9000}. Best is trial 0 with value: 0.8956796940879476.
#
# [MALE] Trial 3/30 | eta=0.0225, depth=7, mcw=2.52, subsample=0.75, colsample=0.79, rounds=8000
# [MALE] Trial 3/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.88744	valid-mlogloss:1.88736
# [200]	train-mlogloss:0.23982	valid-mlogloss:0.32425
# [400]	train-mlogloss:0.15141	valid-mlogloss:0.29589
# [600]	train-mlogloss:0.11182	valid-mlogloss:0.29426
# [792]	train-mlogloss:0.09353	valid-mlogloss:0.29691
# [MALE]   Fold 1 Acc=0.90006 | best_iter=594
# [MALE] Trial 3/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.88715	valid-mlogloss:1.88799
# [200]	train-mlogloss:0.19863	valid-mlogloss:0.29729
# [400]	train-mlogloss:0.12080	valid-mlogloss:0.29625
# [463]	train-mlogloss:0.10689	valid-mlogloss:0.29800
# [MALE]   Fold 1 Acc=0.89780 | best_iter=264
# [MALE] Trial 5/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.83218	valid-mlogloss:1.83379
# [200]	train-mlogloss:0.19607	valid-mlogloss:0.31880
# [400]	train-mlogloss:0.11892	valid-mlogloss:0.31536
# [515]	train-mlogloss:0.09710	valid-mlogloss:0.31956
# [MALE]   Fold 2 Acc=0.89040 | best_iter=317
# [MALE] Trial 5/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.83299	valid-mlogloss:1.83270
# [200]	train-mlogloss:0.19569	valid-mlogloss:0.33334
# [400]	train-mlogloss:0.11966	valid-mlogloss:0.33654
# [445]	train-mlogloss:0.10976	valid-mlogloss:0.33877
# [MALE]   Fold 3 Acc=0.88644 | best_iter=247
# [MALE] Trial 5/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.83302	valid-mlogloss:1.83401
# [200]	train-mlogloss:0.19829	valid-mlogloss:0.32021
# [400]	train-mlogloss:0.12151	valid-mlogloss:0.31567
# [475]	train-mlogloss:0.10579	valid-mlogloss:0.31812
# [MALE]   Fold 4 Acc=0.89322 | best_iter=277
# [MALE] Trial 5/30 • Seed 42 • Fold 5/5
# [0]	train-mlogloss:1.83337	valid-mlogloss:1.83149
# [200]	train-mlogloss:0.20373	valid-mlogloss:0.28272
# [400]	train-mlogloss:0.12625	valid-mlogloss:0.28175
# [511]	train-mlogloss:0.10396	valid-mlogloss:0.28639
# [MALE]   Fold 5 Acc=0.90226 | best_iter=312
# [MALE] Trial 5/30 • Seed 2027 • Fold 1/5
# [0]	train-mlogloss:1.83371	valid-mlogloss:1.83212
# [200]	train-mlogloss:0.20048	valid-mlogloss:0.29242
# [400]	train-mlogloss:0.12310	valid-mlogloss:0.29185
# [442]	train-mlogloss:0.11328	valid-mlogloss:0.29333
# [MALE]   Fold 1 Acc=0.90401 | best_iter=244
# [MALE] Trial 5/30 • Seed 2027 • Fold 2/5
# [0]	train-mlogloss:1.83332	valid-mlogloss:1.83096
# [200]	train-mlogloss:0.19763	valid-mlogloss:0.30223
# [400]	train-mlogloss:0.12084	valid-mlogloss:0.30703
# [445]	train-mlogloss:0.10988	valid-mlogloss:0.30952
# [MALE]   Fold 2 Acc=0.89322 | best_iter=247
# [MALE] Trial 5/30 • Seed 2027 • Fold 3/5
# [0]	train-mlogloss:1.83305	valid-mlogloss:1.83460
# [200]	train-mlogloss:0.19434	valid-mlogloss:0.33192
# [400]	train-mlogloss:0.11905	valid-mlogloss:0.32546
# [548]	train-mlogloss:0.09291	valid-mlogloss:0.32913
# [MALE]   Fold 3 Acc=0.88927 | best_iter=349
# [MALE] Trial 5/30 • Seed 2027 • Fold 4/5
# [0]	train-mlogloss:1.83315	valid-mlogloss:1.83394
# [200]	train-mlogloss:0.19989	valid-mlogloss:0.30097
# [400]	train-mlogloss:0.12327	valid-mlogloss:0.29781
# [511]	train-mlogloss:0.10165	valid-mlogloss:0.30243
# [MALE]   Fold 4 Acc=0.89774 | best_iter=313
# [MALE] Trial 5/30 • Seed 2027 • Fold 5/5
# [0]	train-mlogloss:1.83311	valid-mlogloss:1.83221
# [200]	train-mlogloss:0.19892	valid-mlogloss:0.30253
# [400]	train-mlogloss:0.12211	valid-mlogloss:0.29558
# [551]	train-mlogloss:0.09485	valid-mlogloss:0.30113
# [MALE]   Fold 5 Acc=0.90000 | best_iter=353
# [MALE] Trial 5/30 • Seed 1337 • Fold 1/5
# [0]	train-mlogloss:1.83293	valid-mlogloss:1.83354
# [200]	train-mlogloss:0.19752	valid-mlogloss:0.30792
# [400]	train-mlogloss:0.12008	valid-mlogloss:0.30619
# [507]	train-mlogloss:0.09871	valid-mlogloss:0.31011
# [MALE]   Fold 1 Acc=0.90401 | best_iter=309
# [MALE] Trial 5/30 • Seed 1337 • Fold 2/5
# [0]	train-mlogloss:1.83249	valid-mlogloss:1.83335
# [200]	train-mlogloss:0.19581	valid-mlogloss:0.32494
# [400]	train-mlogloss:0.11992	valid-mlogloss:0.32551
# [502]	train-mlogloss:0.09973	valid-mlogloss:0.32993
# [MALE]   Fold 2 Acc=0.88249 | best_iter=303
# [MALE] Trial 5/30 • Seed 1337 • Fold 3/5
# [0]	train-mlogloss:1.83336	valid-mlogloss:1.83345
# [200]	train-mlogloss:0.19978	valid-mlogloss:0.30632
# [400]	train-mlogloss:0.12092	valid-mlogloss:0.29722
# [579]	train-mlogloss:0.08942	valid-mlogloss:0.30157
# [MALE]   Fold 3 Acc=0.89435 | best_iter=380
# [MALE] Trial 5/30 • Seed 1337 • Fold 4/5
# [0]	train-mlogloss:1.83381	valid-mlogloss:1.83196
# [200]	train-mlogloss:0.19985	valid-mlogloss:0.29735
# [400]	train-mlogloss:0.12343	valid-mlogloss:0.29708
# [491]	train-mlogloss:0.10497	valid-mlogloss:0.30105
# [MALE]   Fold 4 Acc=0.89492 | best_iter=293
# [MALE] Trial 5/30 • Seed 1337 • Fold 5/5
# [0]	train-mlogloss:1.83437	valid-mlogloss:1.83239
# [200]	train-mlogloss:0.20011	valid-mlogloss:0.30424
# [400]	train-mlogloss:0.12241	valid-mlogloss:0.30307
# [466]	train-mlogloss:0.10837	valid-mlogloss:0.30548
# [MALE]   Fold 5 Acc=0.89831 | best_iter=267
# [MALE] Trial 5 mean Acc over seeds: 0.89523
# [I 2025-10-23 18:52:13,769] Trial 4 finished with value: 0.8952276528842483 and parameters: {'eta': 0.044169413118259615, 'max_depth': 5, 'min_child_weight': 1.7443736376977983, 'subsample': 0.8099940124079452, 'colsample_bytree': 0.9497791780756715, 'reg_lambda': 1.5739071656756642, 'reg_alpha': 0.24053987224412593, 'gamma': 0.2878908989569959, 'max_delta_step': 1.9592808661073948, 'num_boost_round': 12000}. Best is trial 0 with value: 0.8956796940879476.
#
# [MALE] Trial 6/30 | eta=0.0313, depth=6, mcw=2.57, subsample=0.80, colsample=0.75, rounds=7000
# [I 2025-10-23 18:55:05,627] Trial 5 finished with value: 0.8955666997376651 and parameters: {'eta': 0.031309328831473644, 'max_depth': 6, 'min_child_weight': 2.567548835875874, 'subsample': 0.8002315984223102, 'colsample_bytree': 0.7537005355139239, 'reg_lambda': 2.153648335164881, 'reg_alpha': 0.06208903578334583, 'gamma': 0.212720468895788, 'max_delta_step': 1.043791537433063, 'num_boost_round': 7000}. Best is trial 0 with value: 0.8956796940879476.
#
# [MALE] Trial 7/30 | eta=0.0315, depth=8, mcw=1.48, subsample=0.81, colsample=0.88, rounds=4000
# [MALE] Trial 7/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.86410	valid-mlogloss:1.86515
# [200]	train-mlogloss:0.14686	valid-mlogloss:0.31691
# [400]	train-mlogloss:0.06327	valid-mlogloss:0.30609
# [521]	train-mlogloss:0.04570	valid-mlogloss:0.31466
# [MALE]   Fold 1 Acc=0.90457 | best_iter=322
# [MALE] Trial 7/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.86351	valid-mlogloss:1.86639
# [200]	train-mlogloss:0.13968	valid-mlogloss:0.33228
# [400]	train-mlogloss:0.06310	valid-mlogloss:0.32888
# [492]	train-mlogloss:0.04896	valid-mlogloss:0.33687
# [MALE]   Fold 2 Acc=0.89322 | best_iter=294
# [MALE] Trial 7/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.86381	valid-mlogloss:1.86593
# [200]	train-mlogloss:0.13895	valid-mlogloss:0.34657
# [400]	train-mlogloss:0.06389	valid-mlogloss:0.35024
# [464]	train-mlogloss:0.05326	valid-mlogloss:0.35568
# [MALE]   Fold 3 Acc=0.88475 | best_iter=266
# [MALE] Trial 7/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.86339	valid-mlogloss:1.86668
# [200]	train-mlogloss:0.14053	valid-mlogloss:0.32961
# [400]	train-mlogloss:0.06439	valid-mlogloss:0.32694
# [478]	train-mlogloss:0.05177	valid-mlogloss:0.33237
# [MALE]   Fold 4 Acc=0.89153 | best_iter=280
# [MALE] Trial 7/30 • Seed 42 • Fold 5/5
# [0]	train-mlogloss:1.86488	valid-mlogloss:1.86521
# [200]	train-mlogloss:0.15115	valid-mlogloss:0.29948
# [400]	train-mlogloss:0.06751	valid-mlogloss:0.29230
# [510]	train-mlogloss:0.05014	valid-mlogloss:0.30141
# [MALE]   Fold 5 Acc=0.89887 | best_iter=312
# [MALE] Trial 7/30 • Seed 2027 • Fold 1/5
# [0]	train-mlogloss:1.86435	valid-mlogloss:1.86560
# [200]	train-mlogloss:0.14204	valid-mlogloss:0.30731
# [400]	train-mlogloss:0.06474	valid-mlogloss:0.30455
# [490]	train-mlogloss:0.05055	valid-mlogloss:0.31080
# [MALE]   Fold 1 Acc=0.90062 | best_iter=292
# [MALE] Trial 7/30 • Seed 2027 • Fold 2/5
# [0]	train-mlogloss:1.86442	valid-mlogloss:1.86449
# [200]	train-mlogloss:0.14877	valid-mlogloss:0.32405
# [400]	train-mlogloss:0.06503	valid-mlogloss:0.31941
# [MALE]   Fold 5 Acc=0.90226 | best_iter=285
# [MALE] Trial 7 mean Acc over seeds: 0.89564
# [I 2025-10-23 18:58:27,202] Trial 6 finished with value: 0.8956419867694739 and parameters: {'eta': 0.031534018455089005, 'max_depth': 8, 'min_child_weight': 1.4827716345683266, 'subsample': 0.8072100444273513, 'colsample_bytree': 0.8831459907874208, 'reg_lambda': 1.5514859097774762, 'reg_alpha': 0.08750514011860037, 'gamma': 0.08480225326858917, 'max_delta_step': 0.10476644050719308, 'num_boost_round': 4000}. Best is trial 0 with value: 0.8956796940879476.
#
# [MALE] Trial 8/30 | eta=0.0298, depth=8, mcw=1.08, subsample=0.93, colsample=0.76, rounds=2000
# [MALE] Trial 8/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.86887	valid-mlogloss:1.87037
# [200]	train-mlogloss:0.17527	valid-mlogloss:0.32001
# [400]	train-mlogloss:0.10071	valid-mlogloss:0.29574
# [600]	train-mlogloss:0.08944	valid-mlogloss:0.29466
# [712]	train-mlogloss:0.08684	valid-mlogloss:0.29502
# [MALE]   Fold 1 Acc=0.90514 | best_iter=513
# [MALE] Trial 8/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.86858	valid-mlogloss:1.87092
# [200]	train-mlogloss:0.17070	valid-mlogloss:0.34154
# [400]	train-mlogloss:0.10033	valid-mlogloss:0.31766
# [600]	train-mlogloss:0.08976	valid-mlogloss:0.31791
# [656]	train-mlogloss:0.08863	valid-mlogloss:0.31810
# [MALE]   Fold 2 Acc=0.89040 | best_iter=458
# [MALE] Trial 8/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.86879	valid-mlogloss:1.87036
# [200]	train-mlogloss:0.16800	valid-mlogloss:0.35212
# [400]	train-mlogloss:0.09982	valid-mlogloss:0.33952
# [520]	train-mlogloss:0.09295	valid-mlogloss:0.34065
# [MALE]   Fold 3 Acc=0.88418 | best_iter=321
# [MALE] Trial 8/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.86851	valid-mlogloss:1.87156
# [200]	train-mlogloss:0.17494	valid-mlogloss:0.34291
# [400]	train-mlogloss:0.10193	valid-mlogloss:0.31587
# [600]	train-mlogloss:0.09177	valid-mlogloss:0.31586
# [665]	train-mlogloss:0.09004	valid-mlogloss:0.31626
# [MALE]   Fold 4 Acc=0.89153 | best_iter=466
# [MALE] Trial 8/30 • Seed 42 • Fold 5/5
# [0]	train-mlogloss:1.87037	valid-mlogloss:1.87075
# [200]	train-mlogloss:0.18348	valid-mlogloss:0.30687
# [400]	train-mlogloss:0.10601	valid-mlogloss:0.28159
# [600]	train-mlogloss:0.09530	valid-mlogloss:0.28121
# [703]	train-mlogloss:0.09240	valid-mlogloss:0.28151
# [MALE]   Fold 5 Acc=0.90113 | best_iter=504
# [MALE] Trial 8/30 • Seed 2027 • Fold 1/5
# [0]	train-mlogloss:1.86940	valid-mlogloss:1.86973
# [200]	train-mlogloss:0.17162	valid-mlogloss:0.31067
# [600]	train-mlogloss:0.09085	valid-mlogloss:0.30202
# [679]	train-mlogloss:0.08932	valid-mlogloss:0.30221
# [MALE]   Fold 3 Acc=0.89322 | best_iter=480
# [MALE] Trial 8/30 • Seed 1337 • Fold 4/5
# [0]	train-mlogloss:1.86932	valid-mlogloss:1.87027
# [200]	train-mlogloss:0.17577	valid-mlogloss:0.31459
# [400]	train-mlogloss:0.10333	valid-mlogloss:0.29072
# [600]	train-mlogloss:0.09336	valid-mlogloss:0.29127
# [641]	train-mlogloss:0.09256	valid-mlogloss:0.29153
# [MALE]   Fold 4 Acc=0.89774 | best_iter=443
# [MALE] Trial 8/30 • Seed 1337 • Fold 5/5
# [0]	train-mlogloss:1.86915	valid-mlogloss:1.86995
# [200]	train-mlogloss:0.17407	valid-mlogloss:0.32198
# [400]	train-mlogloss:0.10362	valid-mlogloss:0.30083
# [596]	train-mlogloss:0.09249	valid-mlogloss:0.30135
# [MALE]   Fold 5 Acc=0.90000 | best_iter=397
# [MALE] Trial 8 mean Acc over seeds: 0.89579
# [I 2025-10-23 19:01:35,822] Trial 7 finished with value: 0.8957923906929066 and parameters: {'eta': 0.029793505813401358, 'max_depth': 8, 'min_child_weight': 1.0821022295593865, 'subsample': 0.9252686210380924, 'colsample_bytree': 0.7584192923553926, 'reg_lambda': 2.041257696790694, 'reg_alpha': 0.36283458583506695, 'gamma': 0.32243005824477966, 'max_delta_step': 0.10570986364332446, 'num_boost_round': 2000}. Best is trial 7 with value: 0.8957923906929066.
#
# [MALE] Trial 9/30 | eta=0.0287, depth=7, mcw=3.88, subsample=0.81, colsample=0.73, rounds=11000
# [MALE] Trial 9/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.87651	valid-mlogloss:1.87836
# [200]	train-mlogloss:0.20679	valid-mlogloss:0.30756
# [400]	train-mlogloss:0.13025	valid-mlogloss:0.29526
# [600]	train-mlogloss:0.09192	valid-mlogloss:0.29848
# [652]	train-mlogloss:0.08535	valid-mlogloss:0.30033
# [MALE]   Fold 1 Acc=0.89667 | best_iter=453
# [MALE] Trial 9/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.87625	valid-mlogloss:1.87811
# [200]	train-mlogloss:0.20641	valid-mlogloss:0.32723
# [400]	train-mlogloss:0.12983	valid-mlogloss:0.31250
# [562]	train-mlogloss:0.09791	valid-mlogloss:0.31705
# [MALE]   Fold 2 Acc=0.89153 | best_iter=363
# [MALE] Trial 9/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.87633	valid-mlogloss:1.87775
# [200]	train-mlogloss:0.20378	valid-mlogloss:0.33796
# [400]	train-mlogloss:0.12854	valid-mlogloss:0.33321
# [513]	train-mlogloss:0.10544	valid-mlogloss:0.33799
# [MALE]   Fold 3 Acc=0.88644 | best_iter=315
# [MALE] Trial 9/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.87607	valid-mlogloss:1.87773
# [200]	train-mlogloss:0.20810	valid-mlogloss:0.32963
# [400]	train-mlogloss:0.13172	valid-mlogloss:0.31418
# [586]	train-mlogloss:0.09655	valid-mlogloss:0.31766
# [MALE]   Fold 4 Acc=0.89209 | best_iter=387
# [MALE] Trial 9/30 • Seed 42 • Fold 5/5
# [0]	train-mlogloss:1.87237	valid-mlogloss:1.87105
# [200]	train-mlogloss:0.21409	valid-mlogloss:0.28809
# [400]	train-mlogloss:0.13610	valid-mlogloss:0.27415
# [558]	train-mlogloss:0.10399	valid-mlogloss:0.27921
# [MALE]   Fold 5 Acc=0.90452 | best_iter=360
# [MALE] Trial 9/30 • Seed 2027 • Fold 1/5
# [0]	train-mlogloss:1.87680	valid-mlogloss:1.87818
# [200]	train-mlogloss:0.21001	valid-mlogloss:0.30134
# [400]	train-mlogloss:0.13303	valid-mlogloss:0.29142
# [562]	train-mlogloss:0.10109	valid-mlogloss:0.29554
# [MALE]   Fold 1 Acc=0.90344 | best_iter=364
# [MALE] Trial 9/30 • Seed 2027 • Fold 2/5
# [0]	train-mlogloss:1.87185	valid-mlogloss:1.87164
# [200]	train-mlogloss:0.20925	valid-mlogloss:0.30920
# [400]	train-mlogloss:0.13294	valid-mlogloss:0.30218
# [510]	train-mlogloss:0.10854	valid-mlogloss:0.30704
# [MALE]   Fold 2 Acc=0.89661 | best_iter=311
# [MALE] Trial 9/30 • Seed 2027 • Fold 3/5
# [0]	train-mlogloss:1.87613	valid-mlogloss:1.87925
# [200]	train-mlogloss:0.20376	valid-mlogloss:0.33762
# [400]	train-mlogloss:0.12874	valid-mlogloss:0.32192
# [600]	train-mlogloss:0.09146	valid-mlogloss:0.32647
# [623]	train-mlogloss:0.08838	valid-mlogloss:0.32704
# [MALE]   Fold 3 Acc=0.88644 | best_iter=424
# [MALE] Trial 9/30 • Seed 2027 • Fold 4/5
# [0]	train-mlogloss:1.87652	valid-mlogloss:1.87835
# [200]	train-mlogloss:0.20771	valid-mlogloss:0.31084
# [400]	train-mlogloss:0.13215	valid-mlogloss:0.29523
# ...
# [0]	train-mlogloss:1.83808	valid-mlogloss:1.84246
# [200]	train-mlogloss:0.15795	valid-mlogloss:0.32281
# [400]	train-mlogloss:0.09480	valid-mlogloss:0.33096
# [404]	train-mlogloss:0.09407	valid-mlogloss:0.33135
# [MALE]   Fold 2 Acc=0.88136 | best_iter=206
# [MALE] Trial 15/30 • Seed 1337 • Fold 3/5
# [0]	train-mlogloss:1.83890	valid-mlogloss:1.84167
# [200]	train-mlogloss:0.16221	valid-mlogloss:0.29783
# [400]	train-mlogloss:0.09494	valid-mlogloss:0.29840
# [470]	train-mlogloss:0.08195	valid-mlogloss:0.30144
# [MALE]   Fold 3 Acc=0.89435 | best_iter=271
# [MALE] Trial 15/30 • Seed 1337 • Fold 4/5
# [0]	train-mlogloss:1.83940	valid-mlogloss:1.84199
# [200]	train-mlogloss:0.16152	valid-mlogloss:0.29092
# [400]	train-mlogloss:0.09720	valid-mlogloss:0.29596
# [449]	train-mlogloss:0.08796	valid-mlogloss:0.29832
# [MALE]   Fold 4 Acc=0.90113 | best_iter=250
# [MALE] Trial 15/30 • Seed 1337 • Fold 5/5
# [0]	train-mlogloss:1.83917	valid-mlogloss:1.84041
# [200]	train-mlogloss:0.16290	valid-mlogloss:0.30077
# [400]	train-mlogloss:0.09739	valid-mlogloss:0.30454
# [436]	train-mlogloss:0.09041	valid-mlogloss:0.30656
# [MALE]   Fold 5 Acc=0.89661 | best_iter=238
# [MALE] Trial 15 mean Acc over seeds: 0.89621
# [I 2025-10-23 19:21:18,765] Trial 14 finished with value: 0.89620691598584 and parameters: {'eta': 0.04417199213486637, 'max_depth': 7, 'min_child_weight': 3.7759526134763193, 'subsample': 0.9167398132557436, 'colsample_bytree': 0.7066801480130646, 'reg_lambda': 0.9980973032983623, 'reg_alpha': 0.5885175001745591, 'gamma': 0.0003543540895635522, 'max_delta_step': 1.5541158907067976, 'num_boost_round': 10000}. Best is trial 14 with value: 0.89620691598584.
#
# [MALE] Trial 16/30 | eta=0.0471, depth=8, mcw=3.04, subsample=0.91, colsample=0.70, rounds=6000
# [MALE] Trial 16/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.83027	valid-mlogloss:1.83405
# [200]	train-mlogloss:0.12597	valid-mlogloss:0.29266
# [400]	train-mlogloss:0.06813	valid-mlogloss:0.30162
# [426]	train-mlogloss:0.06401	valid-mlogloss:0.30335
# [MALE]   Fold 1 Acc=0.90062 | best_iter=227
# [MALE] Trial 16/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.82997	valid-mlogloss:1.83334
# [200]	train-mlogloss:0.12604	valid-mlogloss:0.31244
# [400]	train-mlogloss:0.06816	valid-mlogloss:0.32381
# [410]	train-mlogloss:0.06647	valid-mlogloss:0.32461
# [MALE]   Fold 2 Acc=0.89379 | best_iter=211
# [MALE] Trial 16/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.83005	valid-mlogloss:1.83360
# [200]	train-mlogloss:0.12412	valid-mlogloss:0.33415
# [386]	train-mlogloss:0.07121	valid-mlogloss:0.34917
# [MALE]   Fold 3 Acc=0.88701 | best_iter=188
# [MALE] Trial 16/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.83047	valid-mlogloss:1.83429
# [200]	train-mlogloss:0.12730	valid-mlogloss:0.31705
# [400]	train-mlogloss:0.06926	valid-mlogloss:0.32403
# [427]	train-mlogloss:0.06530	valid-mlogloss:0.32590
# [MALE]   Fold 4 Acc=0.89040 | best_iter=229
# [MALE] Trial 16/30 • Seed 42 • Fold 5/5
# [0]	train-mlogloss:1.82422	valid-mlogloss:1.82427
# [200]	train-mlogloss:0.13095	valid-mlogloss:0.27325
# [396]	train-mlogloss:0.07156	valid-mlogloss:0.28427
# [MALE]   Fold 5 Acc=0.90395 | best_iter=198
# [MALE] Trial 16/30 • Seed 2027 • Fold 1/5
# [0]	train-mlogloss:1.83136	valid-mlogloss:1.83451
# [200]	train-mlogloss:0.12825	valid-mlogloss:0.29119
# [400]	train-mlogloss:0.06990	valid-mlogloss:0.30109
# [408]	train-mlogloss:0.06848	valid-mlogloss:0.30157
# [MALE]   Fold 1 Acc=0.90401 | best_iter=209
# [MALE] Trial 16/30 • Seed 2027 • Fold 2/5
# [0]	train-mlogloss:1.82371	valid-mlogloss:1.82366
# [200]	train-mlogloss:0.12621	valid-mlogloss:0.30360
# [383]	train-mlogloss:0.07096	valid-mlogloss:0.31936
# [MALE]   Fold 2 Acc=0.89266 | best_iter=185
# [MALE] Trial 16/30 • Seed 2027 • Fold 3/5
# [0]	train-mlogloss:1.83029	valid-mlogloss:1.83618
# [200]	train-mlogloss:0.12429	valid-mlogloss:0.32280
# [400]	train-mlogloss:0.06813	valid-mlogloss:0.33153
# [427]	train-mlogloss:0.06390	valid-mlogloss:0.33382
# [MALE]   Fold 3 Acc=0.88870 | best_iter=228
# [MALE] Trial 16/30 • Seed 2027 • Fold 4/5
# [0]	train-mlogloss:1.83073	valid-mlogloss:1.83462
# [200]	train-mlogloss:0.12826	valid-mlogloss:0.29524
# [400]	train-mlogloss:0.07020	valid-mlogloss:0.30517
# [416]	train-mlogloss:0.06750	valid-mlogloss:0.30613
# [MALE]   Fold 4 Acc=0.90226 | best_iter=218
# [MALE] Trial 16/30 • Seed 2027 • Fold 5/5
# [0]	train-mlogloss:1.82982	valid-mlogloss:1.83503
# [200]	train-mlogloss:0.12811	valid-mlogloss:0.29511
# [400]	train-mlogloss:0.07013	valid-mlogloss:0.30156
# [456]	train-mlogloss:0.06184	valid-mlogloss:0.30475
# [MALE]   Fold 5 Acc=0.90339 | best_iter=258
# [MALE] Trial 16/30 • Seed 1337 • Fold 1/5
# [0]	train-mlogloss:1.82349	valid-mlogloss:1.82560
# [200]	train-mlogloss:0.12405	valid-mlogloss:0.30500
# [400]	train-mlogloss:0.06683	valid-mlogloss:0.31340
# [442]	train-mlogloss:0.06036	valid-mlogloss:0.31689
# [MALE]   Fold 1 Acc=0.90344 | best_iter=243
# [MALE] Trial 16/30 • Seed 1337 • Fold 2/5
# [0]	train-mlogloss:1.82967	valid-mlogloss:1.83484
# [200]	train-mlogloss:0.12585	valid-mlogloss:0.32461
# [394]	train-mlogloss:0.07005	valid-mlogloss:0.33929
# [MALE]   Fold 2 Acc=0.88249 | best_iter=196
# [MALE] Trial 16/30 • Seed 1337 • Fold 3/5
# [0]	train-mlogloss:1.83040	valid-mlogloss:1.83373
# [200]	train-mlogloss:0.12817	valid-mlogloss:0.29939
# [400]	train-mlogloss:0.06888	valid-mlogloss:0.30599
# [428]	train-mlogloss:0.06423	valid-mlogloss:0.30790
# [MALE]   Fold 3 Acc=0.89435 | best_iter=229
# [MALE] Trial 16/30 • Seed 1337 • Fold 4/5
# [0]	train-mlogloss:1.83088	valid-mlogloss:1.83438
# [200]	train-mlogloss:0.12869	valid-mlogloss:0.29153
# [400]	train-mlogloss:0.07059	valid-mlogloss:0.30378
# [409]	train-mlogloss:0.06919	valid-mlogloss:0.30454
# [MALE]   Fold 4 Acc=0.90113 | best_iter=210
# [MALE] Trial 16/30 • Seed 1337 • Fold 5/5
# [0]	train-mlogloss:1.83037	valid-mlogloss:1.83289
# [200]	train-mlogloss:0.12937	valid-mlogloss:0.30007
# [395]	train-mlogloss:0.07194	valid-mlogloss:0.31065
# [MALE]   Fold 5 Acc=0.89435 | best_iter=196
# [MALE] Trial 16 mean Acc over seeds: 0.89617
# [I 2025-10-23 19:24:04,592] Trial 15 finished with value: 0.8961691873998433 and parameters: {'eta': 0.04708834822213146, 'max_depth': 8, 'min_child_weight': 3.044745291387459, 'subsample': 0.908967616728709, 'colsample_bytree': 0.7023155607692181, 'reg_lambda': 0.9579033655130055, 'reg_alpha': 0.5928593593565612, 'gamma': 0.011720125910818916, 'max_delta_step': 1.5172782726561327, 'num_boost_round': 6000}. Best is trial 14 with value: 0.89620691598584.
#
# [MALE] Trial 17/30 | eta=0.0522, depth=7, mcw=2.01, subsample=0.95, colsample=0.79, rounds=10000
# [MALE] Trial 17/30 • Seed 42 • Fold 1/5
# [0]	train-mlogloss:1.80871	valid-mlogloss:1.81021
# [200]	train-mlogloss:0.12951	valid-mlogloss:0.29482
# [380]	train-mlogloss:0.07236	valid-mlogloss:0.30323
# [MALE]   Fold 1 Acc=0.89949 | best_iter=182
# [MALE] Trial 17/30 • Seed 42 • Fold 2/5
# [0]	train-mlogloss:1.80824	valid-mlogloss:1.81151
# [200]	train-mlogloss:0.12981	valid-mlogloss:0.31502
# [400]	train-mlogloss:0.06995	valid-mlogloss:0.32665
# [414]	train-mlogloss:0.06743	valid-mlogloss:0.32758
# [MALE]   Fold 2 Acc=0.88588 | best_iter=216
# [MALE] Trial 17/30 • Seed 42 • Fold 3/5
# [0]	train-mlogloss:1.80828	valid-mlogloss:1.80974
# [200]	train-mlogloss:0.12826	valid-mlogloss:0.33580
# [357]	train-mlogloss:0.07741	valid-mlogloss:0.34838
# [MALE]   Fold 3 Acc=0.88588 | best_iter=159
# [MALE] Trial 17/30 • Seed 42 • Fold 4/5
# [0]	train-mlogloss:1.80822	valid-mlogloss:1.81207
# [200]	train-mlogloss:0.13169	valid-mlogloss:0.31504
# [400]	train-mlogloss:0.07017	valid-mlogloss:0.32275
# [424]	train-mlogloss:0.06628	valid-mlogloss:0.32493
# [MALE]   Fold 4 Acc=0.89096 | best_iter=226
# [MALE] Trial 17/30 • Seed 42 • Fold 5/5
# [0]	train-mlogloss:1.81182	valid-mlogloss:1.81143
# [200]	train-mlogloss:0.13528	valid-mlogloss:0.27757
# [388]	train-mlogloss:0.07456	valid-mlogloss:0.28695
# [MALE]   Fold 5 Acc=0.90000 | best_iter=190
# [MALE] Trial 17/30 • Seed 2027 • Fold 1/5
# [0]	train-mlogloss:1.80946	valid-mlogloss:1.80889
# [200]	train-mlogloss:0.13104	valid-mlogloss:0.29252
# [379]	train-mlogloss:0.07412	valid-mlogloss:0.30079
# [MALE]   Fold 1 Acc=0.90288 | best_iter=181
# [MALE] Trial 17/30 • Seed 2027 • Fold 2/5
# [0]	train-mlogloss:1.81099	valid-mlogloss:1.81118
# [200]	train-mlogloss:0.12854	valid-mlogloss:0.30449
# [378]	train-mlogloss:0.07161	valid-mlogloss:0.32076
# [MALE]   Fold 2 Acc=0.89435 | best_iter=179
# [MALE] Trial 17/30 • Seed 2027 • Fold 3/5
# [0]	train-mlogloss:1.80856	valid-mlogloss:1.81307
# [200]	train-mlogloss:0.12805	valid-mlogloss:0.32603
# [400]	train-mlogloss:0.06863	valid-mlogloss:0.33586
# [426]	train-mlogloss:0.06461	valid-mlogloss:0.33803
# [MALE]   Fold 3 Acc=0.88757 | best_iter=227
# [MALE] Trial 17/30 • Seed 2027 • Fold 4/5
# [0]	train-mlogloss:1.80912	valid-mlogloss:1.81219
# [200]	train-mlogloss:0.13184	valid-mlogloss:0.29910
# [W 2025-10-23 19:25:26,910] Trial 16 failed with parameters: {'eta': 0.05224206287787666, 'max_depth': 7, 'min_child_weight': 2.009515572843434, 'subsample': 0.9486245075493898, 'colsample_bytree': 0.7875722316010769, 'reg_lambda': 1.3379576546286218, 'reg_alpha': 0.5919032454454947, 'gamma': 0.06522321791278128, 'max_delta_step': 1.515706677048833, 'num_boost_round': 10000} because of the following error: KeyboardInterrupt().
# Traceback (most recent call last):
#   File "C:\Users\surya\AppData\Roaming\Python\Python310\site-packages\optuna\study\_optimize.py", line 201, in _run_trial
#     value_or_values = func(trial)
#   File "C:\Users\surya\AppData\Local\Temp\ipykernel_23072\2247158446.py", line 53, in objective
#     bst = xgb.train(
#   File "C:\Users\surya\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 729, in inner_f
#     return func(**kwargs)
#   File "C:\Users\surya\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py", line 181, in train
#     bst.update(dtrain, i, obj)
#   File "C:\Users\surya\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py", line 2050, in update
#     _LIB.XGBoosterUpdateOneIter(
# KeyboardInterrupt
# [W 2025-10-23 19:25:26,925] Trial 16 failed with value None.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 5
#       1 # ==============================================================
#       2 # Tune (weighted) per gender
#       3 # ==============================================================
# ----> 5 best_male   = tune_group(X_male, y_male_enc, y_male_lbl, "MALE",   num_class, TRIALS_MALE)
#       6 best_female = tune_group(X_female, y_female_enc, y_female_lbl, "FEMALE", num_class, TRIALS_FEMALE)
#       8 # ==============================================================
#       9 # Train with best params and predict (5-fold avg, weighted)
#      10 # ==============================================================
#
# Cell In[4], line 96, in tune_group(Xg, yg_enc, y_labels_grp, label, num_class, trials)
#      94 print(f"\n[{label}] Robust tuning (weighted): {trials} trials × {len(CV_SEEDS)} seeds × {N_FOLDS}-fold")
#      95 print(f"[INFO] XGBoost {xgb.__version__} | GPU requested: {USE_GPU}")
# ---> 96 study.optimize(objective, n_trials=trials, show_progress_bar=True)
#      98 print(f"[{label}] Best CV Acc: {study.best_value:.5f}")
#      99 print(f"[{label}] Best params:\n{study.best_params}")
#
# File ~\AppData\Roaming\Python\Python310\site-packages\optuna\study\study.py:490, in Study.optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     388 def optimize(
#     389     self,
#     390     func: ObjectiveFuncType,
#    (...)
#     397     show_progress_bar: bool = False,
#     398 ) -> None:
#     399     """Optimize an objective function.
#     400
#     401     Optimization is done by choosing a suitable set of hyperparameter values from a given
#    (...)
#     488             If nested invocation of this method occurs.
#     489     """
# --> 490     _optimize(
#     491         study=self,
#     492         func=func,
#     493         n_trials=n_trials,
#     494         timeout=timeout,
#     495         n_jobs=n_jobs,
#     496         catch=tuple(catch) if isinstance(catch, Iterable) else (catch,),
#     497         callbacks=callbacks,
#     498         gc_after_trial=gc_after_trial,
#     499         show_progress_bar=show_progress_bar,
#     500     )
#
# File ~\AppData\Roaming\Python\Python310\site-packages\optuna\study\_optimize.py:63, in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      61 try:
#      62     if n_jobs == 1:
# ---> 63         _optimize_sequential(
#      64             study,
#      65             func,
#      66             n_trials,
#      67             timeout,
#      68             catch,
#      69             callbacks,
#      70             gc_after_trial,
#      71             reseed_sampler_rng=False,
#      72             time_start=None,
#      73             progress_bar=progress_bar,
#      74         )
#      75     else:
#      76         if n_jobs == -1:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\optuna\study\_optimize.py:160, in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     157         break
#     159 try:
# --> 160     frozen_trial_id = _run_trial(study, func, catch)
#     161 finally:
#     162     # The following line mitigates memory problems that can be occurred in some
#     163     # environments (e.g., services that use computing containers such as GitHub Actions).
#     164     # Please refer to the following PR for further details:
#     165     # https://github.com/optuna/optuna/pull/325.
#     166     if gc_after_trial:
#
# File ~\AppData\Roaming\Python\Python310\site-packages\optuna\study\_optimize.py:258, in _run_trial(study, func, catch)
#     251         assert False, "Should not reach."
#     253 if (
#     254     updated_state == TrialState.FAIL
#     255     and func_err is not None
#     256     and not isinstance(func_err, catch)
#     257 ):
# --> 258     raise func_err
#     259 return trial._trial_id
#
# File ~\AppData\Roaming\Python\Python310\site-packages\optuna\study\_optimize.py:201, in _run_trial(study, func, catch)
#     199 with get_heartbeat_thread(trial._trial_id, study._storage):
#     200     try:
# --> 201         value_or_values = func(trial)
#     202     except exceptions.TrialPruned as e:
#     203         # TODO(mamu): Handle multi-objective cases.
#     204         state = TrialState.PRUNED
#
# Cell In[4], line 53, in tune_group.<locals>.objective(trial)
#      50 dvalid = make_dmatrix(Xva, y_va, None, use_gpu)
#      52 try:
# ---> 53     bst = xgb.train(
#      54         params=params_try,
#      55         dtrain=dtrain,
#      56         num_boost_round=hp["num_boost_round"],
#      57         evals=[(dtrain, "train"), (dvalid, "valid")],
#      58         early_stopping_rounds=EARLY_STOP,
#      59         verbose_eval=_verbose_eval()
#      60     )
#      61     if use_gpu and not GPU_STATUS["used_any"]:
#      62         GPU_STATUS["used_any"] = True
#
# File ~\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py:729, in require_keyword_args.<locals>.throw_if.<locals>.inner_f(*args, **kwargs)
#     727 for k, arg in zip(sig.parameters, args):
#     728     kwargs[k] = arg
# --> 729 return func(**kwargs)
#
# File ~\AppData\Roaming\Python\Python310\site-packages\xgboost\training.py:181, in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks, custom_metric)
#     179 if cb_container.before_iteration(bst, i, dtrain, evals):
#     180     break
# --> 181 bst.update(dtrain, i, obj)
#     182 if cb_container.after_iteration(bst, i, dtrain, evals):
#     183     break
#
# File ~\AppData\Roaming\Python\Python310\site-packages\xgboost\core.py:2050, in Booster.update(self, dtrain, iteration, fobj)
#    2046 self._assign_dmatrix_features(dtrain)
#    2048 if fobj is None:
#    2049     _check_call(
# -> 2050         _LIB.XGBoosterUpdateOneIter(
#    2051             self.handle, ctypes.c_int(iteration), dtrain.handle
#    2052         )
#    2053     )
#    2054 else:
#    2055     pred = self.predict(dtrain, output_margin=True, training=True)
#
# KeyboardInterrupt:
